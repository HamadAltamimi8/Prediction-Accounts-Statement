# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
df = pd.read_csv("/content/MOD SOA_600897.csv")
df
# Out:
#      Date     GL Date         Type Trx Number  Order Number  \
# 0      12    1/3/2021      Invoice   90201138           NaN
# 1      12    1/3/2021      Invoice   90201140           NaN
# 2      12    1/3/2021      Invoice   90201164           NaN
# 3       1    1/3/2021      Invoice   90205347           NaN
# 4       1    1/3/2021      Invoice   90205634           NaN
# ..    ...         ...          ...        ...           ...
# 657    11  30/11/2023      Payment   23-1-798           NaN
# 658    12  16/03/2023  Credit Memo    2073434     3887140.0
# 659    12  31/12/2023      Payment   23-10905           NaN
# 660     2  13/03/2023  Credit Memo    2077397     3885751.0
# 661     2  29/02/2024      Payment   23-10387           NaN
#
#     Amount of INV/DM/CM/PMT     Balance
# 0                110,167.44  110,167.44
# 1                132,756.00  242,923.44
# 2                170,430.00  413,353.44
# 3                 56,221.20  469,574.64
# ...

# %%
df.groupby('Type').count()
# Out:
#              Date  GL Date  Trx Number  Order Number  Amount of INV/DM/CM/PMT  \
# Type
# Credit Memo    77       77          77            63                       77
# Invoice       161      161         161           140                      161
# Payment       424      424         424             0                      424
#
#              Balance
# Type
# Credit Memo       77
# Invoice          161
# Payment          424

# %%
import pandas as pd

# Assuming df is your DataFrame
dummies = pd.get_dummies(df['Type'])

# Converting dummy variables to numbers
dummies_numeric = dummies.astype(int)

# Displaying the numeric dummy variables
display(dummies_numeric)

# Printing the numeric dummy variables
print(dummies_numeric)
# Out:
#      Credit Memo  Invoice  Payment
# 0              0        1        0
# 1              0        1        0
# 2              0        1        0
# 3              0        1        0
# 4              0        1        0
# ..           ...      ...      ...
# 657            0        0        1
# 658            1        0        0
# 659            0        0        1
# 660            1        0        0
# 661            0        0        1
#
# [662 rows x 3 columns]
#      Credit Memo  Invoice  Payment
# 0              0        1        0
# 1              0        1        0
# 2              0        1        0
# 3              0        1        0
# 4              0        1        0
# ..           ...      ...      ...
# 657            0        0        1
# 658            1        0        0
# 659            0        0        1
# 660            1        0        0
# 661            0        0        1
#
# [662 rows x 3 columns]

# %%
merged = pd.concat([df,dummies_numeric],axis='columns')
merged
# Out:
#      Date     GL Date         Type Trx Number  Order Number  \
# 0      12    1/3/2021      Invoice   90201138           NaN
# 1      12    1/3/2021      Invoice   90201140           NaN
# 2      12    1/3/2021      Invoice   90201164           NaN
# 3       1    1/3/2021      Invoice   90205347           NaN
# 4       1    1/3/2021      Invoice   90205634           NaN
# ..    ...         ...          ...        ...           ...
# 657    11  30/11/2023      Payment   23-1-798           NaN
# 658    12  16/03/2023  Credit Memo    2073434     3887140.0
# 659    12  31/12/2023      Payment   23-10905           NaN
# 660     2  13/03/2023  Credit Memo    2077397     3885751.0
# 661     2  29/02/2024      Payment   23-10387           NaN
#
#     Amount of INV/DM/CM/PMT     Balance  Credit Memo  Invoice  Payment
# 0                110,167.44  110,167.44            0        1        0
# 1                132,756.00  242,923.44            0        1        0
# ...

# %%
target = df['Amount of INV/DM/CM/PMT']

# %%
final = merged.drop(['GL Date','Amount of INV/DM/CM/PMT','Type','Trx Number','Order Number','Balance','Credit Memo'], axis='columns')
final
# Out:
#      Date  Invoice  Payment
# 0      12        1        0
# 1      12        1        0
# 2      12        1        0
# 3       1        1        0
# 4       1        1        0
# ..    ...      ...      ...
# 657    11        0        1
# 658    12        0        0
# 659    12        0        1
# 660     2        0        0
# 661     2        0        1
#
# [662 rows x 3 columns]

# %%
import pandas as pd

# Assuming 'target' is the column you're trying to convert:
target = df['Amount of INV/DM/CM/PMT'].replace(',', '', regex=True).astype(float)

# %%
model.fit(final,target)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(final ,target,test_size=0.3)

# %%
print(final .shape)
# Out:
# (662, 3)

# %%
print(target.shape)
# Out:
# (662,)

# %%
print (X_train.shape)
print (X_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (463, 3)
# (199, 3)
# (463,)
# (199,)

# %%
print(X_train)
# Out:
#      Date  Invoice  Payment
# 586     9        0        1
# 52      4        0        1
# 468     3        1        0
# 236     9        0        1
# 129     6        0        1
# ..    ...      ...      ...
# 3       1        1        0
# 136     7        1        0
# 93      5        0        1
# 481     4        1        0
# 398     1        0        1
#
# [463 rows x 3 columns]

# %%
print(y_train)
# Out:
# 586    -99000.00
# 52     -50000.00
# 468      9048.02
# 236    -50000.00
# 129   -375000.00
#          ...
# 3       56221.20
# 136     13616.00
# 93     -10000.00
# 481    245778.00
# 398    -30000.00
# Name: Amount of INV/DM/CM/PMT, Length: 463, dtype: float64

# %%
print(X_test)
# Out:
#      Date  Invoice  Payment
# 211     8        0        1
# 55      4        0        1
# 342    12        0        0
# 282    10        0        1
# 197     8        1        0
# ..    ...      ...      ...
# 151     7        0        1
# 401     1        1        0
# 147     7        0        1
# 150     7        0        1
# 604    11        0        1
#
# [199 rows x 3 columns]

# %%
print(y_test)
# Out:
# 211   -48000.00
# 55    -30000.00
# 342   -15155.16
# 282   -10000.00
# 197    16718.13
#          ...
# 151   -10000.00
# 401     6802.02
# 147   -10000.00
# 150   -10000.00
# 604   -20000.00
# Name: Amount of INV/DM/CM/PMT, Length: 199, dtype: float64

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([-27222.07628294, -32939.69668496,  -3583.04878893, -24363.26608193,
#         86078.13962291,  86078.13962291,  84648.7345224 , -19306.50489449,
#        -25792.67118244, -32939.69668496, -24363.26608193,  80360.51922089,
#        -27222.07628294, -25792.67118244, -24363.26608193, -30080.88648395,
#         76072.30391937, -31510.29158446, -32939.69668496, -31510.29158446,
#        -28651.48138345, -31510.29158446, -21504.45588092, -31510.29158446,
#        -30080.88648395, -22933.86098143,  80360.51922089, -28651.48138345,
#        -28651.48138345, -28651.48138345, -22933.86098143, -35798.50688597,
#        -17877.09979398,  86078.13962291,  78931.11412038, -22933.86098143,
#         -3583.04878893, -34369.10178547,  87507.54472342,  78931.11412038,
#        -32939.69668496,  88936.94982392, -19306.50489449, -12159.47939196,
#        -35798.50688597, -17877.09979398, -30080.88648395, -37227.91198648,
# ...

# %%
model.score(final,target)#Accuracy
# Out:
# 0.51943717624512

# %%
model.predict([[10,1,0]]) # Predict
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([88936.94982392])

# %%
model.predict([[6,0,1]]) # Predict
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([-47529.03225806])

# %%
y_train = y_train.replace(',', '', regex=True).astype(float)
print(y_train)
# Out:
# 586    -99000.00
# 52     -50000.00
# 468      9048.02
# 236    -50000.00
# 129   -375000.00
#          ...
# 3       56221.20
# 136     13616.00
# 93     -10000.00
# 481    245778.00
# 398    -30000.00
# Name: Amount of INV/DM/CM/PMT, Length: 463, dtype: float64

# %%
for column in X_train.columns:
    if X_train[column].dtype == 'y_train':  # Assuming object means string
        X_train[column] = X_train[column].replace(',', '', regex=True).astype(float)

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the RandomForestRegressor
# Example: Set the number of trees in the forest to 20
model = RandomForestRegressor(n_estimators=20)

# Fit the model
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=20)

# %%
model.score(X_test, y_test)
# Out:
# 0.5767026787274299

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(final ,target,test_size=0.3)

# %%
print(X_train.shape,y_train.shape, X_test.shape , y_test.shape )
# Out:
# (463, 3) (463,) (199, 3) (199,)

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.score(X_train, y_train)
# Out:
# 0.49708404775645076

# %%
model.predict([[5,0,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([-23797.2972973])
